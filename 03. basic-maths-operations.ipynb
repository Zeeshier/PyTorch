# %% [markdown]
# # Basic Maths Operations

# %%
import torch

# %%
a = torch.ones(2,3)

# %%
a
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
b = torch.ones(2,3)

# %%
b
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %% [markdown]
# ## Add

# %%
c = torch.add(a,b)

# %%
c
# Out:
# tensor([[2., 2., 2.],
#         [2., 2., 2.]])

# %%
a.add_(b)
# Out:
# tensor([[2., 2., 2.],
#         [2., 2., 2.]])

# %%
a
# Out:
# tensor([[2., 2., 2.],
#         [2., 2., 2.]])

# %% [markdown]
# ## Subtract

# %%
c = torch.sub(a,b)

# %%
c
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %% [markdown]
# ## Multiply

# %%
c = torch.mul(a,b)

# %%
c
# Out:
# tensor([[2., 2., 2.],
#         [2., 2., 2.]])

# %% [markdown]
# ## Division

# %%
c = torch.div(a,b)

# %%
c
# Out:
# tensor([[2., 2., 2.],
#         [2., 2., 2.]])

# %% [markdown]
# ## Transpose

# %%
a.T
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
